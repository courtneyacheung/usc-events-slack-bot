# %%
# ! pip install slack_sdk

# %%
import requests
import datetime
import xml.etree.ElementTree as ET
from slack_sdk import WebClient

import os
SLACK_TOKEN = os.environ["SLACK_TOKEN"]  # get token from environment

# Configuration
URL = "https://calendar.usc.edu/calendar/1.xml"
CHANNEL = "#events-rss"  # or channel ID

client = WebClient(token=SLACK_TOKEN)
today = datetime.date.today()

# Fetch the XML feed
response = requests.get(URL)
response.raise_for_status()
xml_data = response.content
root = ET.fromstring(xml_data)

events_today = []

for item in root.findall(".//item"):
    title = item.findtext("title") or "No title"
    link = item.findtext("link") or ""
    pub_date = item.findtext("{http://purl.org/dc/elements/1.1/}date") or item.findtext("pubDate")

    if pub_date:
        try:
            # Try to parse ISO-style first (<dc:date>)
            if "T" in pub_date:
                event_date = datetime.date.fromisoformat(pub_date.split("T")[0])
            else:
                # Fallback for <pubDate> style
                event_date = datetime.datetime.strptime(pub_date, "%a, %d %b %Y %H:%M:%S %z").date()

            if event_date == today:
                events_today.append(f"{title}\n{link}")
        except Exception as e:
            print("Bad date format:", pub_date, e)

# Post to Slack
if events_today:
    message = "📅 USC events today:\n" + "\n\n".join(f"• {e}" for e in events_today)
    resp = client.chat_postMessage(channel=CHANNEL, text=message)
    print(resp)
else:
    print("No events today.")
# Out:
# {'ok': True, 'channel': 'C09QX1CGREV', 'ts': '1762205911.261819', 'message': {'user': 'U09QJ6KQP98', 'type': 'message', 'ts': '1762205911.261819', 'bot_id': 'B09QX3E10MP', 'app_id': 'A09RCC7JFA4', 'text': ':date: USC events today:\n• Nov 3, 2025: Eco-Monday in Residential Dining at USC Village\n<https://calendar.usc.edu/event/eco-monday-in-residential-dining>\n\n• Nov 3, 2025: Extra Credit Workout Series Powered by Nike\n<https://calendar.usc.edu/event/extra-credit-workout-series-powered-by-nike>\n\n• Nov 3, 2025: Driving Organizational Change with Data\n<https://calendar.usc.edu/event/driving-organizational-change-with-data>\n\n• Nov 3, 2025: Alia Chand: All That Comes After at Roski Studios Building (IFT)\n<https://calendar.usc.edu/event/alia-chand-all-that-comes-after>\n\n• Nov 3, 2025: Katie Jung: Where Shadows Rest at Roski Studios Building (IFT)\n<https://calendar.usc.edu/event/katie-jung-where-shadows-rest>\n\n• Nov 3, 2025: Sarai Mojica: Signifier at Watt Hall (WAH)\n<https://calendar.usc.edu/event/sarai-mojica-signifier>\n\n• Nov 3, 2025: Shea Noland: Heaven is Mānoa Valley in the Rain  at Watt Hall (WAH)\n<https://calendar.usc.edu/event/shea-nolan-heaven-is-manoa-valley-in-the-rain>\n\n• Nov 3, 2025: HERO Seminar: Gastric Cancer in Latinos: Integrating Genomic Science with Health Equity with Dr. Luis Carvajal-Carmona, PhD\n<https://calendar.usc.edu/event/hero-seminar-bridging-genomics-and-population-health-across-disparities-with-dr-luis-carvajal-carmona-phd>\n\n• Nov 3, 2025: CESR Seminar &amp; Brown Bag Series - Fall 2025 at Verna and Peter Dauterive Hall (VPD)\n<https://calendar.usc.edu/event/cesr-seminar-brown-bag-series-fall-2025>\n\n• Nov 3, 2025: Student Affairs Career Pathways with the (PASA/PASA online) Program\n<https://calendar.usc.edu/event/copy-of-student-affairs-career-pathways-with-the-pasapasa-online-program-1506>\n\n• Nov 3, 2025: Chan Alumni Around the World at Center for the Health Professions Building (CHP)\n<https://calendar.usc.edu/event/chan-alumni-around-the-world>\n\n• Nov 3, 2025: Zen Meditation at University Religious Center (URC)\n<https://calendar.usc.edu/event/zen-meditation>\n\n• Nov 3, 2025: Doctor of Philosophy in Education (PhD) Program Information Webinar\n<https://calendar.usc.edu/event/copy-of-doctor-of-philosophy-in-education-phd-program-information-webinar-5013>\n\n• Nov 3, 2025: Nov. 3: Master of Public Administration Progressive Degree Information Session\n<https://calendar.usc.edu/event/nov-3-master-of-public-administration-progressive-degree-information-session>\n\n• Nov 3, 2025: Inaugural WiSE Faculty Distinguished Lecture: Malancha Gupta and Jill McNitt-Gray at Hughes Aircraft Electrical Engineering Center (EEB)\n<https://calendar.usc.edu/event/inaugural-wise-faculty-distinguished-lecture-malancha-gupta-and-jill-mcnitt-gray>\n\n• Nov 3, 2025: MA Curatorial Exhibition: PEEP/SHOW at Roski Graduate Building\n<https://calendar.usc.edu/event/ma-curatorial-exhibition-peepshow>\n\n• Nov 3, 2025: Earth Sciences Seminar - Francis Nimmo at Zumberge Hall (ZHS)\n<https://calendar.usc.edu/event/earth-sciences-seminar-Francis-Nimmo>\n\n• Nov 3, 2025: Career Pathways in Environmental Studies &amp; Sciences at Register for location\n<https://calendar.usc.edu/event/career-pathways-in-environmental-studies-sciences>\n\n• Nov 3, 2025: Career Talk with Professor Francille Wilson at Kaprielian Hall (KAP)\n<https://calendar.usc.edu/event/career-talk-with-professor-francille-wilson>\n\n• Nov 3, 2025: Jazz Night at Carson featuring the Honors Combo and John Clayton at Carson Soundstage (CTV 136)\n<https://calendar.usc.edu/event/jazz-night-at-carson-featuring-the-honors-combo-5071>', 'team': 'T09FYDM7V', 'bot_profile': {'id': 'B09QX3E10MP', 'app_id': 'A09RCC7JFA4', 'user_id': 'U09QJ6KQP98', 'name': 'events-rss', 'icons': {'image_36': 'https://a.slack-edge.com/80588/img/plugins/app/bot_36.png', 'image_48': 'https://a.slack-edge.com/80588/img/plugins/app/bot_48.png', 'image_72': 'https://a.slack-edg ...
